# %%
from pymongo import MongoClient
import pandas as pd
from pymongo import GEOSPHERE

# %%
conn = MongoClient("localhost:27017")

# %%
db = conn.get_database("ironhack")

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack')

# %%
# show collections inside database
db.list_collection_names()
# Out:
# ['countries_smaill', 'companies', 'restaurants', 'books']

# %%
# choose collection to work with
collection = db.get_collection("companies")

# %%
collection.find_one().keys()
# Out:
# dict_keys(['_id', 'name', 'permalink', 'crunchbase_url', 'homepage_url', 'blog_url', 'blog_feed_url', 'twitter_username', 'category_code', 'number_of_employees', 'founded_year', 'founded_month', 'founded_day', 'deadpooled_year', 'tag_list', 'alias_list', 'email_address', 'phone_number', 'description', 'created_at', 'updated_at', 'overview', 'image', 'products', 'relationships', 'competitions', 'providerships', 'total_money_raised', 'funding_rounds', 'investments', 'acquisition', 'acquisitions', 'offices', 'milestones', 'video_embeds', 'screenshots', 'external_links', 'partners'])

# %%
collection.distinct("category_code")
# Out:
# [None,
#  'advertising',
#  'analytics',
#  'automotive',
#  'biotech',
#  'cleantech',
#  'consulting',
#  'design',
#  'ecommerce',
#  'education',
#  'enterprise',
#  'fashion',
#  'finance',
#  'games_video',
#  'government',
#  'hardware',
#  'health',
#  'hospitality',
#  'legal',
#  'local',
#  'manufacturing',
#  'medical',
#  'messaging',
#  'mobile',
#  'music',
#  'nanotech',
#  'network_hosting',
#  'news',
#  'nonprofit',
#  'other',
#  'photo_video',
#  'public_relations',
#  'real_estate',
#  'search',
#  'security',
#  'semiconductor',
#  'social',
#  'software',
#  'sports',
#  'transportation',
#  'travel',
#  'web']

# %%
pd.DataFrame(collection.find({"offices.country_code":"ESP"},{"name":1, "offices.country_code":1, "_id":0}))
# Out:
#                          name  \
# 0                      Google
# 1                    Truphone
# 2                  Brightcove
# 3                  Negonation
# 4                      TokBox
# ..                        ...
# 213              AdLINK Group
# 214                    BuyVIP
# 215  International Sportsbook
# 216                  ITERNOVA
# 217               Xray Imatek
#
#                                                offices
# 0    [{'country_code': 'USA'}, {'country_code': 'US...
# 1    [{'country_code': 'GBR'}, {'country_code': 'US...
# 2    [{'country_code': 'USA'}, {'country_code': 'JP...
# 3                            [{'country_code': 'ESP'}]
# 4    [{'country_code': 'USA'}, {'country_code': 'AU...
# ..                                                 ...
# 213  [{'country_code': 'DEU'}, {'country_code': 'DE...
# 214                          [{'country_code': 'ESP'}]
# 215                          [{'country_code': 'ESP'}]
# ...

# %%
pd.DataFrame(collection.find({"offices.country_code":"AUS"},{"name":1, "offices.country_code":1, "_id":0}))
# Out:
#                           name  \
# 0                       Google
# 1                     Truphone
# 2                       Boonex
# 3                       TokBox
# 4                  KIT digital
# ..                         ...
# 252                        FRV
# 253                  KAZ Group
# 254  CommTel Network Solutions
# 255                     Novera
# 256           Track and Locate
#
#                                                offices
# 0    [{'country_code': 'USA'}, {'country_code': 'US...
# 1    [{'country_code': 'GBR'}, {'country_code': 'US...
# 2                            [{'country_code': 'AUS'}]
# 3    [{'country_code': 'USA'}, {'country_code': 'AU...
# 4    [{'country_code': 'USA'}, {'country_code': 'CZ...
# ..                                                 ...
# 252  [{'country_code': 'ESP'}, {'country_code': 'ES...
# 253                          [{'country_code': 'AUS'}]
# 254  [{'country_code': 'AUS'}, {'country_code': 'AU...
# ...

# %%
list(collection.find({"offices.country_code":"ESP"},{"name":1, "offices.country_code":1, "_id":0}))
# Out:
# [{'name': 'Google',
#   'offices': [{'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'AUS'},
#    {'country_code': 'AUS'},
#    {'country_code': 'CHN'},
#    {'country_code': 'CHN'},
#    {'country_code': 'CHN'},
#    {'country_code': 'HKG'},
#    {'country_code': 'IND'},
#    {'country_code': 'USA'},
#    {'country_code': 'IND'},
#    {'country_code': 'IND'},
#    {'country_code': 'IND'},
# ...

# %%
list(collection.find({"offices.country_code":"ESP"},{"name":1, "office":1, "country_code":1, "_id":0}))
# Out:
# [{'name': 'Google'},
#  {'name': 'Truphone'},
#  {'name': 'Brightcove'},
#  {'name': 'Negonation'},
#  {'name': 'TokBox'},
#  {'name': 'Fon'},
#  {'name': 'eyeOS'},
#  {'name': 'Genoom'},
#  {'name': ']project-open['},
#  {'name': 'EkoPLC'},
#  {'name': 'Starfish Community Group'},
#  {'name': 'Pixoo'},
#  {'name': 'Buongiorno'},
#  {'name': 'The Orchard'},
#  {'name': 'Swotti'},
#  {'name': 'AsesorSeguros'},
#  {'name': 'Allopass'},
#  {'name': 'Spain Holiday'},
#  {'name': 'eRepublik'},
#  {'name': 'Trovit'},
#  {'name': 'BMAT'},
#  {'name': 'Splendia'},
#  {'name': 'All-rankings'},
#  {'name': 'Spotify'},
#  {'name': 'NotePub'},
#  {'name': 'Friend2Friend'},
#  {'name': 'Futurlink'},
#  {'name': 'BlogUpp'},
#  {'name': 'VivoCom'},
#  {'name': 'Wuapi'},
#  {'name': 'Ipoki'},
#  {'name': 'FeedzZ'},
#  {'name': 'Valoris'},
#  {'name': 'vLex'},
#  {'name': 'Jobisjob'},
#  {'name': 'Just Landed'},
#  {'name': 'GeoMe'},
#  {'name': 'Panda Security'},
#  {'name': 'Q-go'},
# ...

# %%
list(_)
# Out:
# [{'name': 'Google',
#   'offices': [{'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'USA'},
#    {'country_code': 'AUS'},
#    {'country_code': 'AUS'},
#    {'country_code': 'CHN'},
#    {'country_code': 'CHN'},
#    {'country_code': 'CHN'},
#    {'country_code': 'HKG'},
#    {'country_code': 'IND'},
#    {'country_code': 'USA'},
#    {'country_code': 'IND'},
#    {'country_code': 'IND'},
#    {'country_code': 'IND'},
# ...

# %%
df = pd.DataFrame(collection)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-3d2d60a6f3d9> in <module>
# ----> 1 df = pd.DataFrame(collection)
#       2 df
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     500         elif isinstance(data, abc.Iterable) and not isinstance(data, (str, bytes)):
#     501             if not isinstance(data, (abc.Sequence, ExtensionArray)):
# --> 502                 data = list(data)
#     503             if len(data) > 0:
#     504                 if is_dataclass(data[0]):
#
# /usr/local/lib/python3.8/site-packages/pymongo/collection.py in __next__(self)
#    3430
#    3431     def __next__(self):
# -> 3432         raise TypeError("'Collection' object is not iterable")
#    3433
#    3434     next = __next__
#
# TypeError: 'Collection' object is not iterable
