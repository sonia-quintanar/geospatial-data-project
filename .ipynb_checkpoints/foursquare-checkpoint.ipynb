# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd
load_dotenv()
# Out:
# True

# %%
vic = {'type': 'Point', 'coordinates': [144.9868546, -37.8026587]}

# %%
tok1 = os.getenv("tok1")
tok2 = os.getenv("tok2")

# %%
#url = "https://favqs.com/api/session"
enlace = 'https://api.foursquare.com/v2/venues/explore'
starbucks_vic = "55ed460-ee94-4800-87db-fc78ec7d13db"

# %%
parametros = { "client_id" : tok1,
          "client_secret" : tok2,
          "v" : "20180323",
          "ll": f"{vic.get('coordinates')[1]},{vic.get('coordinates')[0]}",
          "query": f"{starbucks_vic}",
          "limit" : 10
}

# %%
resp = requests.get (url = enlace, params = parametros)
data = json.loads(resp.text)

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '5fb2fabc164c641f7bd23cf6'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 3234,
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'query': '55ed460 ee94 4800 87db fc78ec7d13db',
#   'totalResults': 25,
#   'suggestedBounds': {'ne': {'lat': -37.797324914661935,
#     'lng': 145.00237581856396},
#    'sw': {'lat': -37.819249904753356, 'lng': 144.9611797890248}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6180d1f964a520ea152ae3',
#        'name': '7-Eleven',
#        'contact': {},
#        'location': {'address': '286 Smith St',
#         'crossStreet': 'at Otter St',
#         'lat': -37.80061200459184,
#         'lng': 144.98416900634766,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -37.80061200459184,
#           'lng': 144.98416900634766}],
#         'distance': 328,
#         'postalCode': '3066',
#         'cc': 'AU',
#         'city': 'Collingwood',
#         'state': 'VIC',
#         'country': 'Australia',
#         'formattedAddress': ['286 Smith St (at Otter St)',
#          'Collingwood VIC 3066',
#          'Australia']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b6180d1f964a520ea152ae3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6af745f964a52069e92be3',
#        'name': '7-Eleven',
#        'contact': {},
#        'location': {'address': '295-297 Brunswick St',
#         'crossStreet': 'at Johnston St',
#         'lat': -37.79832150512064,
#         'lng': 144.9784583934748,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -37.79832150512064,
#           'lng': 144.9784583934748}],
#         'distance': 882,
#         'postalCode': '3065',
#         'cc': 'AU',
#         'city': 'Fitzroy',
#         'state': 'VIC',
#         'country': 'Australia',
#         'formattedAddress': ['295-297 Brunswick St (at Johnston St)',
#          'Fitzroy VIC 3065',
#          'Australia']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b6af745f964a52069e92be3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dbf9240f7b115b875cd7850',
#        'name': 'Tram Stop 13 (86)',
#        'contact': {},
#        'location': {'address': 'Gertrude st',
#         'crossStreet': 'at Brunswick st',
#         'lat': -37.80532403287393,
#         'lng': 144.97738538603795,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -37.80532403287393,
#           'lng': 144.97738538603795}],
#         'distance': 884,
#         'cc': 'AU',
#         'city': 'Fitzroy',
#         'state': 'VIC',
#         'country': 'Australia',
#         'formattedAddress': ['Gertrude st (at Brunswick st)',
#          'Fitzroy VIC',
#          'Australia']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4dbf9240f7b115b875cd7850-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de3647fe4cd056f745a30ed',
#        'name': 'Tram Stop 13 (112)',
#        'contact': {},
#        'location': {'address': 'Brunswick St.',
#         'crossStreet': 'at Gertrude St.',
#         'lat': -37.805646,
#         'lng': 144.97724127942593,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -37.805646,
#           'lng': 144.97724127942593}],
#         'distance': 908,
#         'postalCode': '3065',
#         'cc': 'AU',
#         'city': 'Fitzroy',
#         'state': 'VIC',
#         'country': 'Australia',
#         'formattedAddress': ['Brunswick St. (at Gertrude St.)',
#          'Fitzroy VIC 3065',
#          'Australia']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4de3647fe4cd056f745a30ed-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ddb1c007d8b16381774be2f',
#        'name': 'Tram Stop 13 (96)',
#        'contact': {},
#        'location': {'address': 'Nicholson St',
#         'crossStreet': 'Hanover St',
#         'lat': -37.80290365219116,
#         'lng': 144.97400879859924,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -37.80290365219116,
#           'lng': 144.97400879859924}],
#         'distance': 1130,
#         'postalCode': '3065',
#         'cc': 'AU',
#         'city': 'Fitzroy',
#         'state': 'VIC',
#         'country': 'Australia',
#         'formattedAddress': ['Nicholson St (Hanover St)',
#          'Fitzroy VIC 3065',
#          'Australia']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4ddb1c007d8b16381774be2f-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058754f964a520a38c22e3',
#        'name': 'Flinders Street Station',
#        'contact': {},
#        'location': {'address': 'Flinders St.',
#         'crossStreet': 'at St. Kilda Rd.',
#         'lat': -37.81825331429466,
#         'lng': 144.9670427559116,
#         'distance': 2459,
#         'postalCode': '3000',
#         'cc': 'AU',
#         'city': 'Melbourne',
#         'state': 'VIC',
#         'country': 'Australia',
#         'formattedAddress': ['Flinders St. (at St. Kilda Rd.)',
#          'Melbourne VIC 3000',
#          'Australia']},
#        'categories': [{'id': '4bf58dd8d48988d129951735',
#          'name': 'Train Station',
#          'pluralName': 'Train Stations',
#          'shortName': 'Train Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b058754f964a520a38c22e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb5ec1129c212fb6ca33ca0',
#        'name': 'Tram Stop 65 - Victoria St (78)',
#        'contact': {},
#        'location': {'address': 'Church St',
#         'crossStreet': 'Victoria St',
#         'lat': -37.810863383359255,
#         'lng': 145.00050327176672,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -37.810863383359255,
#           'lng': 145.00050327176672}],
#         'distance': 1508,
#         'cc': 'AU',
#         'city': 'Abbotsford',
#         'state': 'VIC',
#         'country': 'Australia',
#         'formattedAddress': ['Church St (Victoria St)',
#          'Abbotsford VIC',
#          'Australia']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4eb5ec1129c212fb6ca33ca0-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be35659f07b0f47eecff743',
#        'name': 'Tram Stop 13 - Federation Square (3/3a/5/6/16/64/67/72)',
#        'contact': {},
#        'location': {'address': 'St Kilda Rd',
#         'crossStreet': 'Flinders St',
#         'lat': -37.8182192585851,
#         'lng': 144.9678122867459,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -37.8182192585851,
#           'lng': 144.9678122867459}],
#         'distance': 2409,
#         'postalCode': '3000',
#         'cc': 'AU',
#         'city': 'Melbourne',
#         'state': 'VIC',
#         'country': 'Australia',
#         'formattedAddress': ['St Kilda Rd (Flinders St)',
#          'Melbourne VIC 3000',
#          'Australia']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b51',
#          'name': 'Tram Station',
#          'pluralName': 'Tram Stations',
#          'shortName': 'Tram',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4be35659f07b0f47eecff743-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c284a7397d00f4794ac3fea',
#        'name': 'Tram Stop 7 (86/96)',
#        'contact': {},
#        'location': {'address': 'Bourke St.',
#         'crossStreet': 'at Russell St.',
#         'lat': -37.81268312903817,
#         'lng': 144.9685582419506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -37.81268312903817,
#           'lng': 144.9685582419506}],
#         'distance': 1958,
#         'postalCode': '3000',
#         'cc': 'AU',
#         'city': 'Melbourne',
#         'state': 'VIC',
#         'country': 'Australia',
#         'formattedAddress': ['Bourke St. (at Russell St.)',
#          'Melbourne VIC 3000',
#          'Australia']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4c284a7397d00f4794ac3fea-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cbe68c8611abfb70205a505',
#        'name': 'Tram Stop 7 (1/3/3a/5/6/8/16/64/67/72)',
#        'contact': {},
#        'location': {'address': 'Swanston St',
#         'crossStreet': 'at Franklin St',
#         'lat': -37.80804812583497,
#         'lng': 144.96305233582206,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -37.80804812583497,
#           'lng': 144.96305233582206}],
#         'distance': 2177,
#         'postalCode': '3000',
#         'cc': 'AU',
#         'city': 'Melbourne',
#         'state': 'VIC',
#         'country': 'Australia',
#         'formattedAddress': ['Swanston St (at Franklin St)',
#          'Melbourne VIC 3000',
#          'Australia']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4cbe68c8611abfb70205a505-9'}]}]}}

# %%
data.values()
# Out:
# dict_values([{'code': 200, 'requestId': '5fb2ed7b2158a34dc82bf647'}, {'suggestedFilters': {'header': 'Tap to show:', 'filters': [{'name': 'Open now', 'key': 'openNow'}]}, 'suggestedRadius': 3234, 'headerLocation': 'Current map view', 'headerFullLocation': 'Current map view', 'headerLocationGranularity': 'unknown', 'query': 'ab4c54c0 d68a 012e 5619 003048cad9da', 'totalResults': 24, 'suggestedBounds': {'ne': {'lat': -37.77804384833815, 'lng': 145.25297211756225}, 'sw': {'lat': -38.238067184898945, 'lng': 144.93301691183848}}, 'groups': [{'type': 'Recommended Places', 'name': 'recommended', 'items': [{'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4b0b8439f964a520053223e3', 'name': 'D.O.C. Pizza & Mozzarella Bar', 'contact': {}, 'location': {'address': '295 Drummond St', 'crossStreet': 'at Faraday St', 'lat': -37.798954, 'lng': 144.96849, 'labeledLatLngs': [{'label': 'display', 'lat': -37.798954, 'lng': 144.96849}], 'distance': 1667, 'postalCode': '3053', 'cc': 'AU', 'city': 'Carlton', 'state': 'VIC', 'country': 'Australia', 'formattedAddress': ['295 Drummond St (at Faraday St)', 'Carlton VIC 3053', 'Australia']}, 'categories': [{'id': '4bf58dd8d48988d1ca941735', 'name': 'Pizza Place', 'pluralName': 'Pizza Places', 'shortName': 'Pizza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 0, 'usersCount': 0, 'checkinsCount': 0, 'visitsCount': 0}, 'beenHere': {'count': 0, 'lastCheckinExpiredAt': 0, 'marked': False, 'unconfirmedCount': 0}, 'photos': {'count': 0, 'groups': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}}, 'referralId': 'e-0-4b0b8439f964a520053223e3-0'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4b05874ff964a520db8a22e3', 'name': 'Melbourne Cricket Ground (MCG)', 'contact': {}, 'location': {'address': '2 Brunton Ave', 'lat': -37.81962430538924, 'lng': 144.98334288597107, 'labeledLatLngs': [{'label': 'display', 'lat': -37.81962430538924, 'lng': 144.98334288597107}], 'distance': 1913, 'postalCode': '3002', 'cc': 'AU', 'neighborhood': 'Yarra Park', 'city': 'Melbourne', 'state': 'VIC', 'country': 'Australia', 'formattedAddress': ['2 Brunton Ave', 'Melbourne VIC 3002', 'Australia']}, 'categories': [{'id': '4bf58dd8d48988d18a941735', 'name': 'Cricket Ground', 'pluralName': 'Cricket Grounds', 'shortName': 'Cricket', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_cricket_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 0, 'usersCount': 0, 'checkinsCount': 0, 'visitsCount': 0}, 'beenHere': {'count': 0, 'lastCheckinExpiredAt': 0, 'marked': False, 'unconfirmedCount': 0}, 'photos': {'count': 0, 'groups': []}, 'venuePage': {'id': '45086104'}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}}, 'referralId': 'e-0-4b05874ff964a520db8a22e3-1'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4b058750f964a520508b22e3', 'name': 'Queen Victoria Market', 'contact': {}, 'location': {'address': '513 Elizabeth St', 'lat': -37.80689851156586, 'lng': 144.95795433877774, 'distance': 2585, 'postalCode': '3000', 'cc': 'AU', 'city': 'Melbourne', 'state': 'VIC', 'country': 'Australia', 'formattedAddress': ['513 Elizabeth St', 'Melbourne VIC 3000', 'Australia']}, 'categories': [{'id': '50be8ee891d4fa8dcc7199a7', 'name': 'Market', 'pluralName': 'Markets', 'shortName': 'Market', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 0, 'usersCount': 0, 'checkinsCount': 0, 'visitsCount': 0}, 'beenHere': {'count': 0, 'lastCheckinExpiredAt': 0,  ...

# %%
data.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
decoding_data = data.get("response")
#decoding_data

# %%
xxxxxxxx
